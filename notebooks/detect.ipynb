# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# ultralytics library se train and test karenge 
# !git clone https://github.com/Dbhasin1/yolov5.git 
# !pip install -qr yolov5/requirements.txt  #saare matplotlib wagera install karne ke liye 
# %cd yolov5 
import torch
from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 2716, done.
# remote: Total 2716 (delta 0), reused 0 (delta 0), pack-reused 2716
# Receiving objects: 100% (2716/2716), 5.46 MiB | 16.55 MiB/s, done.
# Resolving deltas: 100% (1802/1802), done.
#      |████████████████████████████████| 276kB 5.3MB/s
# ...
# /content/yolov5

# %%
# %cd /content/yolov5/
# !python detect.py --weights weights/best_fin.pt --conf 0.4 --source "/content/testing.mp4"
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (1498/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1499/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1500/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.084s)
# video 1/1 (1501/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1502/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.084s)
# video 1/1 (1503/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1504/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1505/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1506/6495) /content/testing.mp4: 384x640 1 coca-colas, 1 pepsi-symbols, Done. (0.083s)
# video 1/1 (1507/6495) /content/testing.mp4: 384x640 1 coca-colas, Done. (0.083s)
# video 1/1 (1508/6495) /content/testing.mp4: 384x640 1 coca-colas, 1 pepsi-symbols, Done. (0.083s)
# ...

# %%
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue 
for i in range(1, 10000000000):
  continue
